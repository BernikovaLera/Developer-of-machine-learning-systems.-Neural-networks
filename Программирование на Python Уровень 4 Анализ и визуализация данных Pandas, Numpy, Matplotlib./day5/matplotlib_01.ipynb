# %% [markdown]
# ## Анализ и визуализация данных на языке Python.
# ### Библиотека matplotlib
#
# 1. Знакомство с matplotlib
# 3. Различные типы графиков
# 2. Настройка отображения графиков в jupyter notebook
# 3. Оформление графиков
# 4. Вывод нескольких графиков на одной иллюстрации
# 5. Инфографика (круговые, столбчатые диаграммы и т.д.)
#
# **Дополнительно:**
#
# 50 оттенков matplotlib — The Master Plots (с полным кодом на Python)
# https://habr.com/ru/post/468295/
#
#
# [Японские свечи](
# https://ru.stackoverflow.com/questions/954118/%D0%9E%D1%82%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5-%D1%84%D0%B8%D0%BD%D0%B0%D0%BD%D1%81%D0%BE%D0%B2%D1%8B%D1%85-%D0%B1%D0%B8%D1%80%D0%B6%D0%B5%D0%B2%D1%8B%D1%85-%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85-%D0%B2-%D0%B2%D0%B8%D0%B4%D0%B5-%D1%8F%D0%BF%D0%BE%D0%BD%D1%81%D0%BA%D0%B8%D1%85-%D1%81%D0%B2%D0%B5%D1%87%D0%B5%D0%B9) [Github](https://github.com/matplotlib/mplfinance)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
# %matplotlib inline

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# Графики строятся функцией ```plot()```. Ей достаточно передать единственный параметр с вектором данных для отображения:

# %%
data = np.arange(10) ** 2
plt.plot(data);  # нет выходной информации с помощью ';'
# plt.show() # нужно указывать в .py файлах

# %% [markdown]
# Также ей можно передать матрицу:

# %%
plt.plot(np.array([[1, 2, 3, 4], [1, 4, 9, 16]]));

# %% [markdown]
# Для построения полноценного графика функции $y = f(x)$ необходимо вызывать plot с двумя параметрами `plot(x, f(x))`.
#
# При этом удобно задавать диапазон переменной c помощью метода `numpy.linspace()`.

# %%
x = np.linspace(-5, 5, 50)
print(x)
# Out:
# [-5.         -4.79591837 -4.59183673 -4.3877551  -4.18367347 -3.97959184
#  -3.7755102  -3.57142857 -3.36734694 -3.16326531 -2.95918367 -2.75510204
#  -2.55102041 -2.34693878 -2.14285714 -1.93877551 -1.73469388 -1.53061224
#  -1.32653061 -1.12244898 -0.91836735 -0.71428571 -0.51020408 -0.30612245
#  -0.10204082  0.10204082  0.30612245  0.51020408  0.71428571  0.91836735
#   1.12244898  1.32653061  1.53061224  1.73469388  1.93877551  2.14285714
#   2.34693878  2.55102041  2.75510204  2.95918367  3.16326531  3.36734694
#   3.57142857  3.7755102   3.97959184  4.18367347  4.3877551   4.59183673
#   4.79591837  5.        ]

# %% [markdown]
# Выведем график линейной зависимости:

# %%
plt.plot(x, x * 2);
# plt.show()

# %% [markdown]
# На одном поле можно строить несколько графиков:

# %%
arr = np.random.randint(1, 100, (3, 10))
plt.plot(arr);

# %%
x = np.linspace(0, 2, 100)
plt.plot(x, x, ls='--', lw=3)     # линейная зависимость, ls -> linestyle, lw -> linewidth
plt.plot(x, x ** 2, ls=':', c='#ad09a3') # квадратичная зависимость
plt.plot(x, x ** 3, ls='-', c='r') # кубическая
plt.plot(x, np.exp(x), ls='-.', color='black'); # экспоненциальная
# plt.show()

# %% [markdown]
# Простейшую гистограмму можно построить из массива numpy функцией ```hist()```.

# %%
a_rand = np.random.randn(10_000)
plt.hist(a_rand, bins=20);  # by default: bins=10

# %% [markdown]
# Диаграмму рассеяния можно нарисовать  функцией ```scatter()```:

# %%
plt.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30), c='navy', s=100);

# %% [markdown]
# Для рисования стрелок используем функцию ```arrow()```.

# %%
# template: plt.arrow(x1, y1, width, heigth, ...)
plt.arrow(0,0, 3,1, head_width=0.2, color='r', length_includes_head=True)
plt.arrow(0,0, 1,3, head_width=0.2, color='g', length_includes_head=True)
plt.arrow(2,3, 4,4, head_width=0.2, color='b', length_includes_head=True)
plt.show()

# %% [markdown]
# Другие полезные типы графиков:

# %%
x = np.linspace(-1, 1)
# Размер для figure в дюймах
figure, axes = plt.subplots(1, 3, figsize=(12, 4))  # rows == 1, columns == 3, (12, 4) это дюймы

# закрасить пространство между графиками
axes[0].fill_between(x, np.sqrt(np.abs(x)), x**2, color="green", alpha=0.5);
axes[0].set_title("fill_between");

# столбчатая диаграмма
axes[1].bar(np.arange(-5, 6), np.arange(-5, 6)**3, align="center", width=0.5, alpha=0.7)
axes[1].set_title("bar plot")

# ступенчатый график
axes[2].step(x, np.sqrt(np.abs(x)), lw=5, c='brown')  # lw -> linewidth - толщина линии
axes[2].set_title("step ax")

figure.tight_layout() # выравнивание между графиками(subplot);

# %% [markdown]
# ---

# %% [markdown]
# __ЗАДАНИЕ__
# Нарисуйте график синусоиды в диапазоне от $-2\pi$ до $2\pi$

# %%
plt.figure(figsize=(10, 5))
x = np.linspace(-2 * np.pi, 2 * np.pi, 1000)
y = np.sin(x)
plt.plot(x, y, ls='--', color='green')
plt.title('График синусоиды')
plt.grid();

# %% [markdown]
# ----

# %% [markdown]
# ###  Настройка пространства numpy и отображения графиков

# %% [markdown]
# Размеры выводимых графиков могут быть настроены как глобально, так и для каждой иллюстрации отдельно.
#
# Снова построим линейный график и расстроимся из-за его непропорциональности (и других визуальных недостатков):

# %%
plt.plot(np.arange(10));

# %% [markdown]
# Перед построением графика проинициализируйте иллюстрацию, вызвав функцию ```figure()``` с параметром ```figsize```, в котором можно передать размеры картинки в дюймах. Соотношение и будет пропорцией отображаемого графика.

# %%
plt.figure(figsize=(6, 6)) # Размер в дюймах
plt.plot(np.arange(10));
# plt.show()

# %% [markdown]
# Также можно задать нелинейные пропорции осей: логарифмическую, симметричную логарифмическую, логистическую и т.д.

# %%
x = np.linspace(-2, 2, 40)
plt.figure(figsize=(7, 7))
plt.plot(x, x + 1)
plt.plot(x, np.exp(x))
plt.yscale('log')
plt.show()

# %% [markdown]
# Давайте оформим график:
#  - зададим диапазон отображения аргументов и функции
#  - отобразим координатную сетку и оси
#  - зададим метки для осей и самой иллюстрации
#  - выведем легенду.

# %%
plt.figure(figsize=(6, 6))

# зададим диапазон по осям, с полями
margin = .5
# Ограничения по осям
plt.ylim((-1.5, 4.5))
plt.xlim((x.min() - margin, x.max() + margin))

# отобразим координатную сетку и оси
plt.grid(color='grey', linestyle='-', linewidth=1)

# Горизонтальная линия
plt.axhline(0, color='black') # y = 0

# Вертикальная линия
plt.axvline(0, color='black') # x = 0

# зададим метки для осей и самой иллюстрации
plt.xlabel("$x$, аргумент")  # $ код LaTeX $
plt.ylabel("$f(x)$, функция") # Label for y-axis.
plt.title('Линейная и эскпоненциальная зависимости')

# построим график
plt.plot(x, x + 1, label="$f_{1}(x) = x$")
plt.plot(x, np.exp(x), label="$f_{2}(x) = e^x$")

# разместим легенду
plt.legend(loc='upper left')  # loc -> location

plt.savefig('out.png', dpi=300) # сохранили график

plt.show()

# %% [markdown]
# Получилась довольно громоздкая конструкция. Если в вашей работе надо будет представлять все графики в одинаковом оформлении, ее можно убрать в отдельную функцию (а ее, в свою очередь, в модуль). Для этого нам надо ознакомиться с основными объектами matplotlib.
#
# ### Основные объекты matplotlib
#
#  - Объект ```figure``` - сама иллюстрация.
#  - Объект ```axes``` - один из графиков на этой иллюстрации, именно к этому объекту мы будем применять все те методы, с которыми мы ознакомились выше:
#     - ```.plot()```
#     - ```.ylim()``` и ```.xlim()```
#     - ```.title()```, ```.xlabel()```, ```.ylabel()```
#     - и т.д.
#
# Получить экземпляр объекта ```figure``` и требуемое количество ```axes``` можно из функции ```subplots()```, ей надо передать количество графиков по горизонтали и по вертикали. Она возвращает кортеж из иллюстрации(figure) и подграфиков - если их несколько, она вернет их список вторым членом кортежа.
#
# Построим наши графики в соответствии с объектно-ориентированным подходом:

# %%
fig, ax = plt.subplots(1, 1) # пока что нам нужен один график

fig.set_size_inches(6, 6) # figsize=(8, 8)

ax.plot(x, x + 1, label="$f_{1}(x) = x$")
ax.plot(x, np.exp(x), label="$f_{2}(x) = e^x$")
ax.legend(loc='best');
# plt.show()

# %% [markdown]
# Перенесем все оформление в функцию:

# %%
def my_plotter(ax, data_ox, data_oy, **param_dict):

    # отобразим координатную сетку и оси
    ax.grid(color='grey', linestyle='-', linewidth=1)
    ax.axhline(0,color='black') # y = 0
    ax.axvline(0,color='black') # x = 0

    # зададим метки для осей и самой иллюстрации
    ax.set_xlabel("$x$, аргумент")   # Label for x-axis.
    ax.set_ylabel("$f(x)$, функция") # Label for y-axis.

    out = ax.plot(data_ox, data_oy, **param_dict)
    return out

# %%
fig, ax = plt.subplots(1, 1) # пока что нам нужен один график

fig.set_size_inches(6, 6)

ax.set_title('Линейная и эскпоненциальная зависимости')

xx = x + 1 # множество значений для линейной функции

# зададим диапазон по осям, с полями
margin = .5
ax.set_ylim((xx.min()-margin, xx.max()+margin))
ax.set_xlim((x.min()-margin, x.max()+margin))

# построим график
my_plotter(ax, x, xx, label="$f(x) = x$")
my_plotter(ax, x, np.exp(x), label="$f(x) = e^x$")

# разместим легенду
ax.legend(loc='best');

# %% [markdown]
# ### Вывод на одну иллюстрацию несколько графиков сразу
#
# Для этого в matplotlib используется "сеточный" подход: мы мысленно разбиваем нашу иллюстрацию на ячейки и сами определяем, какую часть ячейки будет занимать наш график.
#
# Затем мы обращаемся к функции ```subplot2grid()```, которая принимает следущие аргументы:
#  - ```shape``` - кортеж с формой воображаемой "сетки" по горизонтали и вертикали
#  - ```position``` - кортеж с координатами в ячейках сетки
#  - ```colspan``` - сколько ячеек сетки данный график будет объединять по горизонтали
#  - ```rowspan``` - сколько ячеек сетки данный график будет объединять по вертикали

# %%
fig = plt.figure()
fig.set_size_inches(10, 5)

# Аргументы: форма в виде кортежа с количеством ячеек по горизонтали и вертикали
ax1 = plt.subplot2grid((2, 4), (0, 0), colspan=2)
ax1.set_ylabel('First')
ax2 = plt.subplot2grid((2, 4), (1, 0), colspan=1)
ax2.set_ylabel('Second')
ax3 = plt.subplot2grid((2, 4), (1, 1), colspan=2)
ax3.set_ylabel('Third');
ax4 = plt.subplot2grid((2, 4), (0, 3), rowspan=2)
ax4.set_ylabel('Fourth');
ax5 = plt.subplot2grid((4, 4), (0, 2), rowspan=1)
ax5.set_ylabel('Fifth')
# Автоматическая настройка расстояний между графиками
fig.tight_layout()

# %% [markdown]
# Также можно использовать уже знакомую нам конструкцию ```subplots()```:

# %%
fig, axs = plt.subplots(1, 2)  # один ряд и 2 колонки

fig.set_size_inches(10, 5) # обратите внимание на размер по высоте, мы уменьшили его вдвое!

axs[0].set_title('Линейная зависимость')
axs[1].set_title('Эскпоненциальная зависимость')

x = np.linspace(-2, 2, 40)

xx = x + 1 # множество значений для линейной функции

# зададим диапазон по осям, с полями
margin = .5
for ax in axs:
    ax.set_ylim((xx.min()-margin, xx.max()+margin))
    ax.set_xlim((x.min()-margin, x.max()+margin))



# построим график
my_plotter(axs[0], x, xx, label="$f(x) = x$", color='brown', lw=3)
my_plotter(axs[1], x, np.exp(x), label="$f(x) = e^x$", c='navy', ls='--')


plt.show()

# %% [markdown]
# ---

# %% [markdown]
# __ЗАДАНИЕ__
# Выведите 3 графика по диагонали, два предыдущих и третий график - кубическая зависимость.

# %%
# Ваш код

# %% [markdown]
# ---

# %% [markdown]
# #### Таблица

# %%
import matplotlib.pyplot as plt

val1 = ["{:X}".format(i) for i in range(10)]
val2 = ["{:02X}".format(10 * i) for i in range(10)]
val3 = [["" for c in range(10)] for r in range(10)]

fig, ax = plt.subplots()
# Отключение осей
ax.set_axis_off()
table = ax.table(
    cellText = val3,
    rowLabels = val2,
    colLabels = val1,
    rowColours = ["palegreen"] * 10,
    colColours = ["palegreen"] * 10,
    cellLoc ='center',
    loc ='upper left')

ax.set_title('matplotlib.axes.Axes.table() function Example', fontweight="bold",fontsize=12)

plt.show()

# %% [markdown]
# ### Инфографика
#
# Круговая диаграмма (pie chart) строится функцией ```pie()```. Направление обхода по умолчанию - против часовой стрелки.
# Параметр ```explode``` позволяет задать смещение для некоторых элементов диаграммы. При этом в ```sizes``` могут быть совершенно любые числа, не обязательно процентное соотношение.

# %%
# сделаем графики побольше
plt.rcParams['figure.figsize'] = (7.0, 7.0)

# %%
labels = 'Для ежа', 'Для ужа', 'Для моржа', 'Для стрижа'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # отступ на графике

fig1, ax1 = plt.subplots()
ax1.pie(
    sizes,
    explode=explode,
    labels=labels,
    autopct=lambda x: f'{x*sum(sizes)/100:.0f}%', shadow=True, startangle=90
) # углы против часовой стрелки
plt.show()

# %% [markdown]
# Столбчатые диаграммы с распределением по группам строятся той же функцией ```bar()```, но для построения "надстройки" ей надо передать параметр ```bottom```, который будет содержать данные для "основной" диаграммы:

# %%
N = 5
men_means = (20, 35, 30, 35, 27)
women_means = (25, 32, 34, 20, 25)
ind = np.arange(N)    # расположение x для группы
width = 0.35          # Ширина bar'ов

p1 = plt.bar(ind, men_means, width)
p2 = plt.bar(ind, women_means, width, bottom=men_means)

plt.ylabel('Баллы')
plt.title('Баллы по группе и полу')
plt.xticks(ind, labels=('Г1', 'Г2', 'Г3', 'Г4', 'Г5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('М', 'Ж'))

plt.show()

# %%
fig, ax = plt.subplots()

people = ('Жан-Клод', 'Сильвестр', 'Чак', 'Брюс', 'Арнольд')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))

ax.barh(y_pos, performance, align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()
ax.set_xlabel('Количество фильмов');
